# %%
from pymongo import MongoClient
cluster=MongoClient("mongodb+srv://TraceyYu_1999:123Weareone!@cluster0.fjen0.mongodb.net/TraceyYu_1999?retryWrites=true&w=majority")

# %%
db=cluster["TraceyYuFeb17trial"]
collection=db["carvana_trial_collection"]
table = []
for x in collection.find():
    r = x['Records']
    del x['Records']
    for i in r:
        x.update(i)
    table.append(x)

# %%
table[0]
# Out:
# {'_id': ObjectId('62143b75b3798ade1e52a002'),
#  'VIN': 'VIN: 5XXGT4L38KG337553',
#  'stock_id': '2001434174',
#  'year': '2019',
#  'manufactor': 'Kia',
#  'series': 'Optima',
#  'model': 'LX Sedan 4D',
#  'price': '$23,990',
#  'miles': '38,559',
#  'interior_color': 'Black',
#  'exterior_color': 'White',
#  'cylinder torbo': '4-Cyl',
#  'engine': ' 2.4 Liter',
#  'door_number': '4',
#  'car_type': 'Sedan',
#  'city_gas_mileage': '24',
#  'highway_gas_mileage': '33',
#  'wheel_drive': 'FWD',
#  'key number': '2 Keys',
#  'people_saved_number': '56',
#  'people_viewed_number': '346'}

# %%
import pandas as pd
df = pd.DataFrame(data=data)
df.head()
# Out:
#                         _id                     VIN    stock_id  year  \
# 0  62143b75b3798ade1e52a002  VIN: 5XXGT4L38KG337553  2001434174  2019
# 1  62143b8db3798ade1e52a003  VIN: KNMAT2MT8JP572034  2001487438  2018
# 2  62143ba4b3798ade1e52a004  VIN: 4T1BF1FK3FU010783  2001384162  2015
# 3  62143bbbb3798ade1e52a005  VIN: 5XXGT4L34JG208532  2001438401  2018
# 4  62143bd2b3798ade1e52a006  VIN: 1C4PJLABXGW303520  2001551660  2016
#
#   manufactor    series                model    price   miles interior_color  \
# 0        Kia    Optima          LX Sedan 4D  $23,990  38,559          Black
# 1     Nissan     Rogue  SV Sport Utility 4D  $24,990  36,600          Black
# 2     Toyota     Camry          LE Sedan 4D  $21,590  26,970           Gray
# 3        Kia    Optima           S Sedan 4D  $23,990  42,719          Black
# 4       Jeep  Cherokee         Sport SUV 4D  $19,990  65,039          Black
#
#    ... cylinder torbo      engine door_number car_type city_gas_mileage  \
# ...

# %%
#check null value
def check_null(d):
    a= d.isnull().any()
    for i,v in a.items():
        if v == True:
            print (i)
    return ('check_null: pass')

check_null(df)
# Out:
# 'check_null: pass'

# %%
a= df['people_saved_number'].values
a[a == 'no people saved info' ] = '0'

b = df['people_viewed_number'].values
b[b == 'no people viewed info' ] = '0'

# %%
df['people_saved_number'] = pd.to_numeric(df['people_saved_number'])
df['people_viewed_number'] = pd.to_numeric(df['people_viewed_number'])
#df['miles'] = pd.to_numeric(df['miles'])
new_df = df.groupby(['manufactor']).sum().sort_values('people_saved_number', ascending=False)
new_df.reset_index(inplace=True)
new_df
# Out:
#     manufactor  people_saved_number  people_viewed_number  \
# 0       Nissan                 1720                  2258
# 1        Honda                 1245                  2903
# 2       Toyota                  928                  2150
# 3         Ford                  852                  2402
# 4          Kia                  846                  2112
# 5         Jeep                  833                   881
# 6      Hyundai                  804                  1756
# 7    Chevrolet                  599                  1709
# 8   Volkswagen                  598                  1064
# 9        Mazda                  359                  1414
# 10       Buick                  332                   988
# 11        MINI                  261                   601
# 12       Dodge                  226                   549
# 13       Lexus                  225                   695
# 14    Chrysler                  198                   134
# ...

# %%
new_df.pivot(index = 'manufactor',
        columns = 'series',
        values = 'people_saved_number')
